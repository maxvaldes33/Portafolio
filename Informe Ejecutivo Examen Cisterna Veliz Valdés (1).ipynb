# %% [markdown]
# # Prueba 1 Informe Ejecutivo
# Integrantes: Miguel Cisterna, Matias Veliz, Maximiliano Valdes

# %% [markdown]
# ##Contexto:
# El videojuego counter strike global ofensive, es un videojuego que consiste de un modo principal de 5v5, el cual esta separado en partidos y a su ves estos partidos estan separados por rondas, para poder ganar rondas los jugadores deben matar
# a todo el equipo contrario, por su parte los equipos se dividen entre terrorista y contra terrorista, los cuales juegan en distintos mapas, de los cuales en este dataframe son los 4 principales del modo de juego competitivo, a continuacion se presentaran nuestras hipotesis e inteneramos refutarlas o valida

# %% [markdown]
# ##Nuestras Hipotesis
# 1.- Un usuario que este sobre el 50% de la media tendra un asesinato como minimo por ronda
# >
# 2.- Un headshot es igual a una kill
# >
# 3.- El equipo que mas gasta en armas gana más seguido
# >
# 4.- El que mas mata mas gana.

# %% [markdown]
# ##Hipotesis uno
# Como podemos apreciar, en el informe al presentar la estadistica descriptiva de RoundKills o por su traduccion asesinatos por ronda, podemos apreciar que a partir de recien el 75% de los usuarios tiende a tener 1 asesinato por ronda, por lo cual nuestra hipotesis queda anulada.

# %% [markdown]
# ![asesinato.png](data:image/png;base64,...)

# %% [markdown]
# ###Hipotesis dos
# Como podemos ver en el informe y en las siguientes imagens, un headshot es un 66% de probabilidad de que este sea una kill.
# >
# En este Grafico de dispersion, podemos ver que es directo, ya que si las kills por partida son mayor, la cantidad de disparos a la cabeza tambien es mayor. Por lo que podemos decir que nuestra hipotesis puede ser aceptada, ya que a mayor headshot mas kills podemos tener.

# %% [markdown]
# ![Probabilidad condicional.png](data:image/png;base64,...)

# %% [markdown]
# ##Hipotesis tres
# Como se ve representado en las siguientes imagenes, que fueron extraidas del informe, podemos apresiar que aunque los contra-terroristas en promedio gasten mas estos no tienen una diferencia notoria entre ambos equipos, es mas aunque gasten mas, los terroristas ganan mas partidas. Por lo que nuestra hipotesis queda anulada.

# %% [markdown]
# ![imagen_2024-01-13_231156198.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Hipotesis cuatro

# %% [markdown]
# Como podemos apreciar, el que mas mata no siempre gana, ya que false al ser derrota y true victoria, podemos apreciar de manera clara que los que mas pierden incluso tienen en promedio mayor cantidad de kill, ya que el 50% de los datos se encuentran entre 5 y 14 aproximadamente, y los que ganan (true), tienen promedios menores de asesinatos.

# %% [markdown]
# ![victoria.png](data:image/png;base64,...)

# %% [markdown]
# ##Conclusión:
# >
# Como conclusion podemos afirmar que la curva de aprendizaje de este videojuego puede llegar a ser bastante compleja, ya que recien a partir del 75% de los usuarios empiezan a hacer una kill o mas por ronda, lo cual en otros videojuegos puede tomarse como el minimo, por otra parte podemos verificar que independientemente del lado que elijas para jugar, tus probabilidades de ganar son iguales.
#
# >
# Por otro lado cabe recalcar que los usuarios que mas matan no tienen asegurada la victoria, ya que al ser un juego de equipo, los usuarios tienen que jugar de manera coperativa y de no ser así la victoria se aleja mucho de ellos independiente de que maten mucho o no.

# %% [markdown]
# #Prueba 2

# %% [markdown]
# ####Coeficiente de correlacion

# %% [markdown]
# ![imagen_2024-01-19_230850384.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##**Analisis**
# >
# Como podemos observar en el mapa de calor y en el coeficiente de correlacion, hay variables las cuales no estan siendo mostradas o siendo correlacionadas, puesto que estas al tener un valor de tipo object, no se pueden trabajar en las correlaciones, de igual forma estas variables seran trabajadas a futuro para poder correlacionarlas.
# >
# ###**Valores de correlación directa**
# Por su parte podemos observar en el mapa de calor y en las matriz de correlacion que por ejemplo, roundkills esta correlacionado de manera directa con roundheadshots, ademas otro ejemplo puede ser PrimaryAssaultRifle con TeamStartingEquipmentValue y RoundStartingEquipmentValue, puesto que estas armas al ser las mas usadas tienden a influir directamente con estas otras variables.
# >
# ###**Valores de correlación inversa**
# Como podemos ver las variables que son tipo PrimaryXXXX: Categorizada en AssaultRifle, SniperRifle, SMG, Heavy y Pistol. Nos presenta el porcentaje de uso arma clasificada como primaria. Por lo que podemos decir que la variable de tipo Primary AssaultRifle y Pistol son variables inversas, ya que el uso de una anula el uso de la otra. Ademas primarypiston es inversa con las variables de valor de equipamiento, puesto que los jugadores (EJ: cuando pierden 2 rondas seguidas) tienden a hacer lo que se conoce como ronda economica, la cual consiste en no comprar armas para en la siguiente ronda comprar equipamiento pesado, y la pistola al ser gratuita tiende a ser mas usada en este tipo de rondas, por lo cual el costo del equipamiento de los equipos baja

# %% [markdown]
# Ahora veamos la correlacion con numeros.
# Se puede observar que existe una correlacion del 68% entre las kills en una ronda y los disparos a la cabeza en una ronda

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Y aqui se puede observar que existe una correlacion del 62% entre el presupuesto inicial del equipo y el rifle de asalto.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##KPIs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Conclusion 2:

# %% [markdown]
# ![image.png](
#
# )

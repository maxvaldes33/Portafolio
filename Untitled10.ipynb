# %%
# Trabajando con tipos de datos
x = 29
y = 15.9
z = True
c = 2 + 5j
s = "Soy un string"
sx = 'Tambien soy un string'

# %%
# Imprime las variables
print(x)
print(y)
print(z)
print(c)
print(s)
print(sx)
# Out:
# 29
# 15.9
# True
# (2+5j)
# Soy un string
# Tambien soy un string

# %%
# Operadores de string (cadenas de carateres)
x = "cadena"
y = 'libre'
# Operador de concatenación
z = x + y
# Operador de repetición
w = y*4
# Imprime las variables
print(z)
print(x,y) # Notar la concatenación implicita de las cadenas e insertando el␣
,→espacio de separación
print(w)
# Out:
#   File "<ipython-input-6-61da3db739b0>", line 11
#     →espacio("de", "separación")
#     ^
# SyntaxError: invalid character '→' (U+2192)

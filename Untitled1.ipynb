# %%
import numpy as np

# %%
v= np.array([8,0,3,1,5])
print(v)
# Out:
# [8 0 3 1 5]

# %%
A = np.array([[5,4,7],[3,8,1]])
print(A.shape)
# Out:
# (2, 3)

# %%
a = 2
b = 4
c = 7.435

print(a)
print(b)
print(c)
print(a+b)
print(b-c)
print(b*a)
# Out:
# 2
# 4
# 7.435

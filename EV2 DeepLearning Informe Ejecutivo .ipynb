# %% [markdown]
# **Evaluacion 2 Deep Learning**

# %% [markdown]
# ![Captura de pantalla 2023-08-25 212928.png](data:image/png;base64,...)

# %% [markdown]
# **Integrantes:**
#
#
#
# *   Cristian Jeldres
# *   Lorena Reyes
# *   Maximiliano Valdes
#
# **Profesor:**
#
# *   Carlos Correa
#
# **Sección:**
#
# *   003D

# %% [markdown]
# # **Fase 1: Entendimiento del negocio**

# %% [markdown]
# En esta primera fase, nos enfocaremos en comprender los aspectos clave relacionados con la clasificacion de imagenes de moda utilizando el conjunto de datos Fashion-MNIST que consta de imagenes en escala de grises de 28 x 28 de 70.000 productos de moda de 10 categorias, con 7000 imágenes por categoría.
# Nuestro conjunto de entrenamiento consta de 60.000 imagenes y el conjunto de prueba tiene 10.000 imágenes.
# Para desarrollar este proyecto trabajaremos bajo la metodología de CRISP-DM la cual consta con 6 fases:
#   * Entendimiento del negocio
#   * Entendimiento de los datos
#   * Preparacion de los datos
#   * Modelado
#   * Evaluacion del modelo
#   * Despliegue
#
# Esta metodología garantizará un enfoque sistemático y efectivo en todas las etapas del proyecto.
#
# **Objetivos del negocio:**
#
# * El propósito general de este proyecto es poder mejorar la clasificación de las imágenes de moda del comercio electrónico.
# * Se busca resolver el desafío de categorizar correctamente productos de moda en 10 categorias distintas.
#
# **Criterios de éxito del negocio:**
#
# * Mediremos el éxito del modelo mediante métricas como la precisión de la clasificacíon con el objetivo de lograr una alta precisíon en la clasificacion de las imagenes.

# %% [markdown]
# # **Fase 2: Entendimiento de los datos**

# %% [markdown]
#  El conjunto de datos Fashion-MNIST que consta de imagenes en escala de grises de 28 x 28 de 70.000 productos de moda de 10 categorias, con 7000 imágenes por categoría

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Este código es para cargar el conjunto de datos Fashion-MNIST desde la web:
#
# Definición de la función load_fashion_mnist_online(): Esta función se encarga de cargar el conjunto de datos Fashion-MNIST.
#
#
# URLs de las etiquetas e imágenes: Se definen dos URLs, labels_url y images_url, que apuntan a los archivos comprimidos de las etiquetas e imágenes del conjunto de datos Fashion-MNIST respectivamente.
#
#
# Descarga de los archivos comprimidos: Se utilizan las funciones requests.get() para descargar los archivos comprimidos de las etiquetas e imágenes.
#
#
# Descompresión y lectura de los datos: Se descomprimen los archivos descargados utilizando gzip.decompress(). Luego, se leen los datos descomprimidos utilizando np.frombuffer().
#
# Para las etiquetas, se leen como enteros sin signo de 8 bits (np.uint8), y para las imágenes, se leen como enteros sin signo de 8 bits y se redimensionan en un arreglo tridimensional de tamaño (número de etiquetas, 28, 28), donde 28x28 es el tamaño de cada imagen.
#
#
# Retorno de las imágenes y etiquetas: Finalmente, la función retorna las imágenes y etiquetas cargadas.
#
#
# Carga del conjunto de datos: Se llama a la función load_fashion_mnist_online() para cargar las imágenes y etiquetas del conjunto de datos Fashion-MNIST desde la web, y se almacenan en las variables images y labels respectivamente.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En esta imagen se puede apreciar como estan etiquetada desde el origen todas las imagenes para que podamos comprobarlas en un futuro con los resultados que nos entregan los modelos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Luego se agregan etiquetas con nombres reales para que puedan ser mas faciles de identificar para todos los usuarios

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Comprobamos como estan divididas las categorias para apreciar su distribucion, por lo que podemos apreciar cada una tiene un 10% de los datos cada una.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se corrobora lo anterior mencionado

# %% [markdown]
# # **Fase 3: Preparacion de los datos**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Fase 4: Modelado**

# %% [markdown]
# ## **Perceptron**

# %% [markdown]
# ### **Sigmoid / SGD**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se muestran buenos valores, puesto que el modelo esta categorizando una sola clase, por lo que esta siendo preciso con esa categoria.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# aqui podemos ver la perdida del modelo a lo largo de las epocas, como podemos ver la perdida total es baja ya que a medida que va abanzando el porcentaje va disminuyendo hasta casi llegar a 0.09 (lo que seria un 10%) con sobre el 96% de acierto.

# %% [markdown]
# ### **Hard_sigmoid / SGD**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Despues de ver las metricas podemos afirmar que esta funcion de activacion no es ideal ya que presenta un gran porcentaje de perdida, a pesar de tener una exactitud alta, esto se puede deber a la gran cantidad de perdida.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# aqui podemos ver que los modelos son irregulares y que no aprenden de manera correcta.

# %% [markdown]
# ### **Sigmoid / Adam**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Entrega una buena precision y una baja perdida, por lo que puede ser correcta esta funcion de activacion para el modelo.|

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a pesar de tener buenas metricas podemos ver que el modelo funciona de manera irregular, teniendo en prueba una menor cantidad de acierto.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se comparan los modelos lado a lado para poder apreciar de mejor manera cuales son los mejores o peores para descartar o compilar con esos modelos.

# %% [markdown]
# ## **MLP**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# podemos ver que la perdida a lo largo de las epocas van reduciendo y por ende va mejorando a lo que va aprendiendo el modelo

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se logra entender lo mismo de la precision, ya que esta se va mejorando a lo largo de las epocas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aqui podemos ver que el modelo va reconociendo en gran mayoria de manera correcta las imagenes. aunque hay casos en los cuales debido a la baja resolusion incluso al ojo humano le cuesta reconocerlo

# %% [markdown]
# **Mejorado**

# %% [markdown]
# A continuacion se mejorara el modelo y podremos verlo como va avanzando y aprendiendo mejor.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aquí una representacion de como la perdida va disminuyendo a lo largo de las epocas, pero a pesar de esto no disminuye del 20%

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Por otra parte podemos ver que la precision del modelo es alta, por lo cual es capaz de identificar de manera correcta las imagenes y cartegorizarlas con 92% de presicion

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aquí podemos ver una representacion de como el modelo es capaz de identificar las imagenes y categorizar de manera correcta, aunque hay casos que incluso a nosotros, teniendo imagenes muy borrosas cuesta identificar.

# %% [markdown]
# ## **FCFF**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aqui podemos ver que la perdida de las primeras epocas va disminuyendo a lo largo el modelo avanza, teniendo como resultado que estas funcionan con un 30% de perdida final

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Este histograma muestra que el acierto va mejorando a medida que avanzan las epocas y que el modelo va aprendiendo a lo largo que se le va entregando mayor informacion, teniendo como resultado un 90% de acierto

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Aqui estan los ejemplos de como el modelo va aprendiendo y reconoce de manera correcta con FCFF, aunque MLP funciona de manera mas correcta.

# %% [markdown]
# # Examen Transveral
# # Caso Banco "Monopoly/Dormammu"

# %% [markdown]
# ![Vijeo del monopoly](https://infogate.cl/wp-content/uploads/2017/03/se%C3%B1or-monopoly-tokens.jpg)

# %% [markdown]
# # Fase 1: Comprencion del negocio, Business Understanding

# %% [markdown]
# El banco con capitales extranjeros, Dormammu, busca hacer un estudio a los clientes del banco Monopoly para poder detectar patrones de comportomamiento y poder analizar como será su estrategia para poder abordar estos nuevos clientes dado el uso que ellos hacen de sus productos financieros.

# %% [markdown]
# # Fase 2: Comprender los datos, Data Understanding

# %% [markdown]
# ## Importa el archivo excel y las librerias a utilizar

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
archivo_excel = "C:\\Users\\musrr\\Downloads\\Base_clientes_Monopoly.xlsx"
dataframe = pd.read_excel(archivo_excel)
print(dataframe.head())
# Out:
#    Id  Subsegmento Sexo  Region  Edad     Renta  Antiguedad  Internauta  \
# 0   1          160    M    13.0    43       NaN         130           1
# 1   2          160    H    13.0    46  143640.0          69           1
# 2   3          170    H    13.0    45  929106.0          24           1
# 3   4          151    H    13.0    46  172447.0         134           0
# 4   5          170    H    13.0    46  805250.0         116           0
#
#    Adicional  Dualidad  ...  ColMx_T01  PagoNac_T01  PagoInt_T01  EeccNac_T01  \
# 0          1         0  ...        0.0        33000          0.0    1099866.0
# 1          0         0  ...        0.0       300000          0.0     214592.0
# 2          1         0  ...        0.0       216676          0.0          0.0
# 3          1         0  ...        0.0        60000          0.0     272762.0
# 4          1         1  ...        0.0       272925          0.0     249562.0
#
# ...

# %% [markdown]
# ## Verificar los nombres de las columnas en el DataFrame

# %%
print(dataframe.columns)
# Out:
# Index(['Id', 'Subsegmento', 'Sexo', 'Region', 'Edad', 'Renta', 'Antiguedad',
#        'Internauta', 'Adicional', 'Dualidad',
#        ...
#        'ColMx_T01', 'PagoNac_T01', 'PagoInt_T01', 'EeccNac_T01', 'EeccInt_T01',
#        'UsoL1_T01', 'UsoL2_T01', 'UsoLI_T01', 'IndRev_T01', 'target'],
#       dtype='object', length=574)

# %% [markdown]
# ## Crear un histograma con valores de Renta

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=dataframe, x='Renta', bins=40, kde=True, color='skyblue', alpha=0.7)
plt.xlabel('Distribucion de la Renta')
plt.ylabel('Frecuencia')
plt.title('Distribución de Renta')
plt.legend(labels=['Distribución', 'KDE'])
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Ajusta las etiquetas del eje x
renta_ticks = [i * 1000000 for i in range(11)]
plt.xticks(renta_ticks, rotation=0)
plt.show()
# Out:
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Valores máximos y minimos de la Renta**

# %%
valor_maximo = dataframe['Renta'].max()
valor_minimo = dataframe['Renta'].min()

print(f"Valor máximo de Renta: {valor_maximo}")
print(f"Valor mínimo de Renta: {valor_minimo}")
# Out:
# Valor máximo de Renta: 13089327.0
# Valor mínimo de Renta: 1.0

# %% [markdown]
# Como podemos analizar en el histograma, y teniendo en cuenta que el valor maximo de renta es 13.089.327 y el minimo es 1, podemos concluir que 0,0
# parte desde 1 y que 1.0 en el histograma es igual a 13.089.327, ademas como se puede apreciar, gran parte de los datos se encuentran hasta el 0.2,
# lo que es igual al 20%, por ende, gran parte de los datos se encuentran en un valor como maximo de 2.617.865, por su parte la distribucion muestra
# que los datos tienen mayor frecuenca de estar dentre de 0,0 y 0,1, teniendo como punto de mayor repeticion, con más de 20000 usuarios, una renta
# aproximada de 872.622.

# %% [markdown]
# ## Distribución de Edad

# %%
plt.figure(figsize=(10, 6))
sns.histplot(dataframe['Edad'], bins=20, kde=True)
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.title('Distribución de Edad')
plt.show()
# Out:
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Como se puede apreciar en el histograma, la mayor parte de los usuarios del banco monopoly se encuentran dentro de las edades de 20 a 40 años de edad,
# Teniendo esto en cuenta, buscamos cual es la edad mas comun con el siguiente codigo:

# %%
edad_mas_comun = dataframe['Edad'].mode()
print(f"Edad más común: {edad_mas_comun.values[0]}")
# Out:
# Edad más común: 27

# %% [markdown]
# ## Contar la cantidad de 0 y 1 en la columna "target"

# %%
conteo_clases = dataframe['target'].value_counts()
plt.figure(figsize=(6, 4))
plt.bar(conteo_clases.index, conteo_clases.values, color=['blue', 'red'])
plt.xlabel('Indicador pago de deuda')
plt.ylabel('Frecuencia')
plt.title('Distribucion de pagos')
plt.xticks(conteo_clases.index, ['Paga total', 'Pago mínimo'])
plt.show()

# %% [markdown]
# Como se puede apreciar en el grafico, gran parte de los usuarios tiende a pagar el total de sus deudas, con el siguiente codigo se muestran en numeros
# exactos cuantos son:

# %%
conteo_pagos = dataframe['target'].value_counts()
print("Cantidad de 0 (Paga total):", conteo_pagos[0])
print("Cantidad de 1 (Pago mínimo):", conteo_pagos[1])
# Out:
# Cantidad de 0 (Paga total): 46524
# Cantidad de 1 (Pago mínimo): 4600

# %% [markdown]
# Como se puede apreciar, solo 4600 personas pagan el minimo, mientras que 46524 pagan el total, eso es mas de 10 veces de los que pagan el minimo,
# por conclusion la gente tiende a ser responsable con sus cuentas y deudas

# %% [markdown]
# ## Distribución de Sexo

# %%
sns.countplot(data=dataframe, x='Sexo')
plt.xlabel('Sexo')
plt.ylabel('Frecuencia')
plt.title('Distribución de Sexo')
plt.show()
# Out:
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# La distribucion de genero dentro del banco monopoly es bastante pareja, ya que por como se representa en el grafico, la brecha entre hombres y mujeres
# no es tan alta, con el siguiente codigo contara cuantos son de cada genero:

# %%
conteo_sexo = dataframe['Sexo'].value_counts()
print("Cantidad de Mujeres:", conteo_sexo['M'])
print("Cantidad de Hombres:", conteo_sexo['H'])
# Out:
# Cantidad de Mujeres: 23713
# Cantidad de Hombres: 27410

# %% [markdown]
# ## Distribución Tarjetas de Credito

# %%
value_counts_tc = dataframe['TC'].value_counts()
# Gráfico de barras para el número de tarjetas de crédito
plt.figure(figsize=(8, 5))
sns.countplot(data=dataframe, x='TC')
plt.xlabel('Número de Tarjetas de Credito')
plt.ylabel('Frecuencia')
plt.title('Distribución del Número de Tarjetas de Credito')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Como se puede apreciar, la mayor cantidad de los usuarios tiende a tener entre 1 y 2 tarjetas de credito,
# con el siguiente codigo contara cuantas son de cada cantidad, ya que el minimo es 1 y el maximo es 12

# %%
conteo_tc = dataframe['TC'].value_counts()
print("Cantidad de gente con 1 tarjeta:", conteo_tc[1])
print("Cantidad de gente con 2 tarjetas:", conteo_tc[2])
print("Cantidad de gente con 3 tarjetas:", conteo_tc[3])
print("Cantidad de gente con 4 tarjetas:", conteo_tc[4])
print("Cantidad de gente con 5 tarjetas:", conteo_tc[5])
print("Cantidad de gente con 6 tarjetas:", conteo_tc[6])
print("Cantidad de gente con 7 tarjetas:", conteo_tc[7])
print("Cantidad de gente con 8 tarjetas:", conteo_tc[8])
print("Cantidad de gente con 9 tarjetas:", conteo_tc[9])
print("Cantidad de gente con 10 tarjetas:", conteo_tc[10])
print("Cantidad de gente con 11 tarjetas:", conteo_tc[11])
print("Cantidad de gente con 12 tarjetas:", conteo_tc[12])
# Out:
# Cantidad de gente con 1 tarjeta: 24085
# Cantidad de gente con 2 tarjetas: 19807
# Cantidad de gente con 3 tarjetas: 4772
# Cantidad de gente con 4 tarjetas: 2002
# Cantidad de gente con 5 tarjetas: 285
# Cantidad de gente con 6 tarjetas: 124
# Cantidad de gente con 7 tarjetas: 30
# Cantidad de gente con 8 tarjetas: 13
# Cantidad de gente con 9 tarjetas: 3
# Cantidad de gente con 10 tarjetas: 1
# Cantidad de gente con 11 tarjetas: 1
# Cantidad de gente con 12 tarjetas: 1

# %% [markdown]
# ## Boxplot de Edad

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Boxplot de la variable "Edad"
plt.figure(figsize=(8, 5))
sns.boxplot(data= dataframe, x='Edad')
plt.xlabel('Edad')
plt.title('Boxplot de la Edad')
plt.show()
# Out:
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ## Mapa de Correlación

# %%
columnas_seleccionadas = ['Antiguedad', 'Edad', 'Debito', 'Ctacte', 'Cuentas', 'Monoproducto', 'Adicional',  'TC', 'CUPO_L1', 'CUPO_MX', 'CUPO_L2']
dataframe_seleccionado = dataframe[columnas_seleccionadas]
correlation_matrix = dataframe_seleccionado.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True)
plt.title('Mapa de Correlación')
plt.show()

# %% [markdown]
# Como se pude ver en el grafico se ve que las variables con mayor correlacion son CUPO_L1 y CUPO_MX ya que el cupo internacional se puede ver directamente afectado a el cupo que tiene la persona a nivel nacional.

# %% [markdown]
# ## Explicacion de los datos de manera estadistica

# %%
# Seleccionar las columnas relevantes
columnas_seleccionadas = ['Renta', 'Edad', 'Antiguedad', 'Cuentas', 'TC', 'CUPO_L1', 'FacAI_T12','FacAN_T12', 'PagoInt_T12', 'PagoNac_T12']

# Crear un nuevo DataFrame con las columnas seleccionadas
dataframe_seleccionado = dataframe[columnas_seleccionadas]

# Obtener estadísticas descriptivas
estadisticas_descriptivas = dataframe_seleccionado.describe()

# Mostrar las estadísticas descriptivas
print(estadisticas_descriptivas)
# Out:
#               Renta          Edad    Antiguedad       Cuentas            TC  \
# count  3.775900e+04  51124.000000  51124.000000  51124.000000  51124.000000
# mean   6.630771e+05     38.702879     38.896154      1.407206      1.732376
# std    4.092795e+05     13.302573     35.672549      0.550357      0.877470
# min    1.000000e+00      9.000000      6.000000      1.000000      1.000000
# 25%    4.199990e+05     28.000000     14.000000      1.000000      1.000000
# 50%    5.670120e+05     35.000000     25.000000      1.000000      2.000000
# 75%    8.149035e+05     46.000000     54.000000      2.000000      2.000000
# max    1.308933e+07    104.000000    324.000000      5.000000     12.000000
#
#             CUPO_L1      FacAI_T12     FacAN_T12   PagoInt_T12   PagoNac_T12
# count  5.112400e+04   42873.000000  4.287300e+04  4.287300e+04  4.287300e+04
# mean   1.133187e+06     373.337824  1.724188e+03  5.590727e+03  7.256960e+04
# ...

# %% [markdown]
# Como se puede ver en las estadisticas descriptivas, los datos presentados anteriormente se vuelven a confirmar, ya que el minimo es 1 y el maximo son
# más de 13 millones, por otro lado, se puede ver que la media (mean) y la mediana (50%) es distinta, siendo la media mas alta que la mediana, por otro lado la edad nos muestra como el maximo de edad es 104 y el minimo es de 9, teniendo como media esta un valor de 38, por su parte la antiguedad nos muestra que el valor minimo es 6, lo que se puede traducir a que lleva 6 mese en el banco y que el maximo es 324 meses, lo que es igual a 27 años, por otra parte las cuentas, como es obvio tienen que partir desde 1 ya que si fuera 0 no seria cliente del banco, por otro lado, las tarjetas de credito (TC) muestran como es obligatorio el tener tarjeta de credito, puesto que el minimo es 1

# %% [markdown]
# # Fase 3: Preparacion de los datos, Data Preparing

# %% [markdown]
# **Contamos la cantidad de nulos en la tabla de Renta**

# %%
nulos_renta = dataframe['Renta'].isnull().sum()
print("Cantidad de valores nulos en 'Renta':", nulos_renta)
# Out:
# Cantidad de valores nulos en 'Renta': 13365

# %% [markdown]
# **Le remplazamos los valores null por el promedio de la Renta**

# %%
dataframe['Renta'].fillna(dataframe['Renta'].mean(), inplace=True)

# %% [markdown]
# **Volvemos a contar la cantidad de nulos en la tabla Renta**

# %%
nulos_renta = dataframe['Renta'].isnull().sum()
print("Cantidad de valores nulos en 'Renta':", nulos_renta)
# Out:
# Cantidad de valores nulos en 'Renta': 0

# %% [markdown]
# Se rellenan los datos faltantes de renta con el promedio (mean), en la tabla a continuacion se puede comparar con la anterior:

# %%
estadisticas_renta = dataframe['Renta'].describe()
print(estadisticas_renta)
# Out:
# count    5.112400e+04
# mean     6.630771e+05
# std      3.517356e+05
# min      1.000000e+00
# 25%      4.669655e+05
# 50%      6.630771e+05
# 75%      7.095002e+05
# max      1.308933e+07
# Name: Renta, dtype: float64

# %% [markdown]
# ## La nueva distribucion de la renta

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=dataframe, x='Renta', bins=40, kde=True, color='skyblue', alpha=0.7)
plt.xlabel('Distribucion de la Renta')
plt.ylabel('Frecuencia')
plt.title('Distribución de Renta')
plt.legend(labels=['Distribución', 'KDE'])
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Ajusta las etiquetas del eje x
renta_ticks = [i * 1000000 for i in range(11)]
plt.xticks(renta_ticks, rotation=0)
plt.show()
# Out:
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Acá se puede apreciar como el punto mas alto de la renta cambio, ya que la media relleno a los valores faltantes, la ventaja de rellenar con la media
# es que se pueden completar los datos y no van a alterar los valores de estadiscas

# %% [markdown]
# ## Ahora cambiaremos los valores nulos de la tabla PIN por 0

# %% [markdown]
# Con el siguiente codigo xontaremos los nulos y despues los remplazaremos a los valores faltantes en la tabla CambioPin por 0, ya que existian registros solo si los usuarios habian cambiado su pin en al menos una ocasión, de no ser así, era null

# %% [markdown]
# **Contamos los nulos de la tabla cambio de pin:**

# %%
nulos_pin = dataframe['CambioPin'].isnull().sum()
print("Cantidad de valores nulos en 'CambioPin':", nulos_pin)
# Out:
# Cantidad de valores nulos en 'CambioPin': 19388

# %% [markdown]
# **Rellenamos los valores null por valores de 0**

# %%
dataframe['CambioPin'].fillna(0, inplace=True)

# %% [markdown]
# **Volvemos a contar el valor de pin para verificar que no tiene nulls**

# %%
nulos_pin = dataframe['CambioPin'].isnull().sum()
print("Cantidad de valores nulos en 'CambioPin':", nulos_pin)
# Out:
# Cantidad de valores nulos en 'CambioPin': 0

# %% [markdown]
# ## Modelamos para ver la cantidad de gente que a cambiado de pin contra los que nunca han cambiado de pin

# %%
sns.countplot(data=dataframe, x='CambioPin')
plt.xlabel('¿Cambio el pin?')
plt.ylabel('Cantidad de gente')
plt.title('Distribución de CambioPin')
plt.show()
# Out:
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\musrr\miniconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Esto lo que muestra es que la gran parte de las personas han cambiado su pin en al menos una ocasión

# %% [markdown]
# # Fase 4: Modelado, Modeling

# %% [markdown]
# # Fase 5: Evaluación, Evaluation

# %% [markdown]
# # Fase 6: Implementación o despliegue, Deployment

# %% [markdown]
# # Fase 7: Monitorización, Monitoring
